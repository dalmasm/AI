# %% [markdown]
# <a href="https://colab.research.google.com/github/dalmasm/AI/blob/Data-Science/AI_Engineer_2025_Transformers_Langchain_Basic_start.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AI Engineer 2025 - Langchain
#
# ## Objetivo
# Most
#
# ### Detalles
# - Blah
#
# ### Referencia
# Ver clase 47
#
# ### Consultas
# albertcapacitaciondigital@gmail.com

# %%
#Normalmente se instala langchain tambien pero vamos a usar Gemini de
# Google en un ejemplo simple, asi que instalamos el componente que nos permite
# trabajar con la API de Gemini de una manera standard
# !pip install -U langchain-google-genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 34.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.15
#     Uninstalling google-ai-generativelanguage-0.6.15:
#       Successfully uninstalled google-ai-generativelanguage-0.6.15
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-generativeai 0.8.5 requires google-ai-generativelanguage==0.6.15, but you have google-ai-generativelanguage 0.6.18 which is incompatible.
# ...

# %%
#Esta seccion sirve para interactuar con Google Collab
# Si no detecta que esta cargada la Key de Gemini,la pide en linea
# Obtener la key gratis en https://aistudio.google.com
import getpass
import os

if not os.environ.get("GOOGLE_API_KEY"):
  os.environ["GOOGLE_API_KEY"] = getpass.getpass(AIzaSyA3IfnL4FgxRg-gUp-X4BFJ3p19F3Lb04A)

# %%
#Abstraccion de LLM de Google (solo de Google, usar init_chat_model para uso generico)
from langchain_google_genai import ChatGoogleGenerativeAI

#El modelo que ponen aca tiene que soportar generacion obviamente
llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash", temperature=0.7)

# %%
#Orquestracion basica de componentes
#Prompt, un modelo de AI, y formatear el response standard
# (no todos los modelos tienen el mismo formato)
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
# Definir prompt
prompt = PromptTemplate.from_template("What is the capital of {country}?")

#Definir chain
chain = prompt | llm | StrOutputParser()

# Ejecutar chain
result = chain.invoke({"country": "Antartica"})
print(result)
# Out:
# Antarctica does not have a capital city. It is a continent governed by international treaties, and no single country owns it. Research stations are scattered across the continent, but they are not considered capitals.

# %%
# Definir prompt
prompt = PromptTemplate.from_template(
    "Give me three fun facts about {animal} suitable for kids."
)

#Definir chain
chain = prompt | llm | StrOutputParser()

# Ejecutar chain
result = chain.invoke({"animal": "spiders"})
print(result)
# Out:
# Okay, here are three fun spider facts perfect for kids:
#
# 1.  **Spiders are Super Silk Makers!** Spiders don't just use silk for webs! They use it to build homes, wrap up their food, and even make little parachutes to fly through the air! It's like they have their own superpower!
#
# 2.  **Spiders are Amazing Acrobats!** Many spiders can walk upside down on their webs! They have tiny claws on their feet that help them grip the silk, so they can hang out and hunt without falling!
#
# 3.  **Spiders are Master Chefs... Kind Of!** Spiders can't chew their food! Instead, they spit digestive juices onto their prey to turn it into a soupy meal that they can slurp up! Ewww, but also cool!
